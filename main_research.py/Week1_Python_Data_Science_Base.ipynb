# %%
import pandas as pd

# 替换为你解压后的文件路径
eda_df = pd.read_csv(r"D:\Hydro_AI_Project\data\EDA.csv")
hr_df = pd.read_csv(r"D:\Hydro_AI_Project\data\HR.csv")

print("✅ EDA皮电数据读取成功！维度：", eda_df.shape)
print("✅ HR心率数据读取成功！维度：", hr_df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # 替换为你解压后的文件路径
# ----> 4 eda_df = pd.read_csv(r"D:\Hydro_AI_Project\data\EDA.csv")
#       5 hr_df = pd.read_csv(r"D:\Hydro_AI_Project\data\HR.csv")
#       7 print("✅ EDA皮电数据读取成功！维度：", eda_df.shape)
#
# ...

# %%
import pandas as pd

# 👇 把引号里的内容，替换成你复制的真实文件路径，前面必须加r！
eda_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2\EDA.csv")
hr_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2\HR.csv")

print("✅ EDA皮电数据读取成功！维度：", eda_df.shape)
print("✅ HR心率数据读取成功！维度：", hr_df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # 👇 把引号里的内容，替换成你复制的真实文件路径，前面必须加r！
# ----> 4 eda_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2\EDA.csv")
#       5 hr_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2\HR.csv")
#       7 print("✅ EDA皮电数据读取成功！维度：", eda_df.shape)
#
# ...

# %%
import pandas as pd

# ====================== 完全匹配你当前路径的代码 ======================
# 路径前必须加 r，彻底解决Windows反斜杠转义问题
eda_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\EDA.csv")
hr_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\HR.csv")
temp_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\TEMP.csv")
acc_df = pd.read_csv(r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\ACC.csv")

# ====================== 数据读取验证 ======================
print("="*60)
print("✅ 所有生物传感数据读取成功！")
print(f"📊 EDA皮电数据维度：{eda_df.shape}（样本数 × 特征数）")
print(f"📊 HR心率数据维度：{hr_df.shape}")
print(f"📊 TEMP体温数据维度：{temp_df.shape}")
print(f"📊 ACC加速度数据维度：{acc_df.shape}")

# ====================== 第1周测试节点：空值过滤 + 均值/标准差计算 ======================
print("\n" + "="*60)
print("📊 第1周测试节点：EDA皮电数据统计结果")
# 1. 过滤含空值的行
eda_clean = eda_df.dropna(axis=0)
print(f"清洗前样本量：{eda_df.shape[0]} | 清洗后有效样本量：{eda_clean.shape[0]}")

# 2. 计算并输出每列的平均值和标准差（保留4位小数，符合科研规范）
print("\n🔍 EDA数据每列平均值：")
print(eda_clean.mean().round(4))

print("\n🔍 EDA数据每列标准差：")
print(eda_clean.std().round(4))

print("\n🎉 第1周测试节点（生物传感数据部分）完美通过！")
# Out:
# ...
# ✅ 所有生物传感数据读取成功！
# 📊 EDA皮电数据维度：(31495, 1)（样本数 × 特征数）
# 📊 HR心率数据维度：(7866, 1)
# 📊 TEMP体温数据维度：(31497, 1)
# 📊 ACC加速度数据维度：(251971, 3)
#
# ...
# 📊 第1周测试节点：EDA皮电数据统计结果
# 清洗前样本量：31495 | 清洗后有效样本量：31495
#
# 🔍 EDA数据每列平均值：
# 1495437325.000000    0.5479
# dtype: float64
#
# 🔍 EDA数据每列标准差：
# 1495437325.000000    0.4612
# dtype: float64
#
# 🎉 第1周测试节点（生物传感数据部分）完美通过！

# %%
import pandas as pd

# 替换为你空气质量数据的真实路径
air_df = pd.read_csv(r"D:\Hydro_AI_Project\data\ShenyangPM20100101_20151231.csv")

# 1. 数据读取验证
print("="*60)
print("✅ 空气质量数据读取成功！")
print(f"📊 数据维度：{air_df.shape}（样本数 × 特征数）")

# 2. 第1周测试节点：空值过滤 + 均值/标准差计算
print("\n" + "="*60)
print("📊 第1周测试节点：空气质量数据统计结果")
# 过滤含空值的行
air_clean = air_df.dropna(axis=0)
print(f"清洗前样本量：{air_df.shape[0]} | 清洗后有效样本量：{air_clean.shape[0]}")

# 计算并输出每列的平均值和标准差
print("\n🔍 空气质量数据每列平均值：")
print(air_clean.mean().round(4))

print("\n🔍 空气质量数据每列标准差：")
print(air_clean.std().round(4))

print("\n🎉 第1周测试节点（空气质量部分）完美通过！")
print("\n🎉 第1周全部测试节点100%完成！")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 # 替换为你空气质量数据的真实路径
# ----> 4 air_df = pd.read_csv(r"D:\Hydro_AI_Project\data\ShenyangPM20100101_20151231.csv")
#       6 # 1. 数据读取验证
#       7 print("="*60)
#
# ...

# %%
# Out:
# ...
# ✅ 🎉 所有数据文件读取成功！路径配置完美！
# 📊 空气质量数据维度: (52584, 17)
# 📊 EDA皮电数据维度: (31495, 1)
# 📊 HR心率数据维度: (7866, 1)
# 📊 TEMP体温数据维度: (31497, 1)
# 📊 ACC加速度数据维度: (251971, 3)
#
# ...
# 📊 第1周测试节点：空气质量数据统计结果
# 🔧 清洗前样本量: 52584 | 清洗后有效样本量: 19038
#
# 🔍 空气质量数据每列平均值：
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 54
#      52 # 2. 计算并输出每列的平均值和标准差 (保留4位小数)
#      53 print("\n🔍 空气质量数据每列平均值：")
# ---> 54 print(air_clean.mean().round(4))
#      56 print("\n🔍 空气质量数据每列标准差：")
#      57 print(air_clean.std().round(4))
#
# File ~\miniconda3\envs\hydro_ai\lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)
#   11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
# ...

# %%
# Out:
# ...
# All files read successfully! Path configuration is perfect!
# Air data shape: (52584, 17)
# EDA data shape: (31495, 1)
# HR data shape: (7866, 1)
# TEMP data shape: (31497, 1)
# ACC data shape: (251971, 3)
#
# ...
# Week 1 Test Node: Air Quality Data Statistics
# Cleaning | Before: 52584 | After: 19038
#
# Air Quality Mean Values:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 37
#      34 print(f"Cleaning | Before: {air_df.shape[0]} | After: {air_clean.shape[0]}")
#      36 print("\nAir Quality Mean Values:")
# ---> 37 print(air_clean.mean().round(4))
#      39 print("\nAir Quality Std Deviation:")
#      40 print(air_clean.std().round(4))
#
# File ~\miniconda3\envs\hydro_ai\lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
# ...

# %%
import pandas as pd

air_path = r"D:\Hydro_AI_Project\pm2.5\ShenyangPM20100101_20151231.csv"
eda_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\EDA.csv"
hr_path  = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\HR.csv"
temp_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\TEMP.csv"
acc_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\ACC.csv"

try:
    air_df = pd.read_csv(air_path)
    eda_df = pd.read_csv(eda_path)
    hr_df  = pd.read_csv(hr_path)
    temp_df = pd.read_csv(temp_path)
    acc_df = pd.read_csv(acc_path)
    print("OK")
    print(air_df.shape)
    print(eda_df.shape)
except:
    print("Path or file error")
# Out:
# OK
# (52584, 17)
# (31495, 1)

# %%
import pandas as pd

# 路径（已经验证完全正确）
air_path = r"D:\Hydro_AI_Project\pm2.5\ShenyangPM20100101_20151231.csv"
eda_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\EDA.csv"
hr_path  = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\HR.csv"
temp_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\TEMP.csv"
acc_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\ACC.csv"

# 1. 读取数据（已验证成功）
air_df = pd.read_csv(air_path)
eda_df = pd.read_csv(eda_path)
hr_df  = pd.read_csv(hr_path)
temp_df = pd.read_csv(temp_path)
acc_df = pd.read_csv(acc_path)

print("="*60)
print("✅ 所有数据读取成功！")
print(f"📊 空气质量数据维度：{air_df.shape}")
print(f"📊 EDA皮电数据维度：{eda_df.shape}")
print(f"📊 HR心率数据维度：{hr_df.shape}")

# ============== 第1周测试节点：空值过滤 + 均值/标准差 ==============
print("\n" + "="*60)
print("📊 第1周测试节点：空气质量数据统计结果")
# 过滤含空值的行
air_clean = air_df.dropna(axis=0)
print(f"🔧 清洗前样本量：{air_df.shape[0]} | 清洗后有效样本量：{air_clean.shape[0]}")

# 计算每列平均值和标准差（保留4位小数）
print("\n🔍 空气质量数据每列平均值：")
print(air_clean.mean().round(4))

print("\n🔍 空气质量数据每列标准差：")
print(air_clean.std().round(4))

print("\n🎉 第1周测试节点（空气质量部分）完美通过！")

# 补充EDA数据统计（完整覆盖生物传感部分）
print("\n" + "="*60)
print("📊 第1周测试节点：EDA皮电数据统计结果")
eda_clean = eda_df.dropna(axis=0)
print(f"🔧 清洗前样本量：{eda_df.shape[0]} | 清洗后有效样本量：{eda_clean.shape[0]}")

print("\n🔍 EDA数据每列平均值：")
print(eda_clean.mean().round(4))

print("\n🔍 EDA数据每列标准差：")
print(eda_clean.std().round(4))

print("\n🎉 第1周测试节点（生物传感部分）完美通过！")
print("\n🎉 第1周全部任务100%完成！第一阶段第1周正式收官！")
# Out:
# ...
# ✅ 所有数据读取成功！
# 📊 空气质量数据维度：(52584, 17)
# 📊 EDA皮电数据维度：(31495, 1)
# 📊 HR心率数据维度：(7866, 1)
#
# ...
# 📊 第1周测试节点：空气质量数据统计结果
# 🔧 清洗前样本量：52584 | 清洗后有效样本量：19038
#
# 🔍 空气质量数据每列平均值：
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 32
#      30 # 计算每列平均值和标准差（保留4位小数）
#      31 print("\n🔍 空气质量数据每列平均值：")
# ---> 32 print(air_clean.mean().round(4))
#      34 print("\n🔍 空气质量数据每列标准差：")
#      35 print(air_clean.std().round(4))
#
# File ~\miniconda3\envs\hydro_ai\lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)
#   11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# ...

# %%
import pandas as pd

# 路径配置（已验证完全正确，不要动）
air_path = r"D:\Hydro_AI_Project\pm2.5\ShenyangPM20100101_20151231.csv"
eda_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\EDA.csv"
hr_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\HR.csv"
temp_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\TEMP.csv"
acc_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\ACC.csv"

# 读取数据
air_df = pd.read_csv(air_path)
eda_df = pd.read_csv(eda_path)
hr_df = pd.read_csv(hr_path)
temp_df = pd.read_csv(temp_path)
acc_df = pd.read_csv(acc_path)

# 打印成功信息
print("All files read successfully!")
print("Air data shape:", air_df.shape)
print("EDA data shape:", eda_df.shape)
print("HR data shape:", hr_df.shape)

# 第1周测试节点：空值过滤 + 均值/标准差
air_clean = air_df.dropna(axis=0)
print("\nCleaning | Before:", air_df.shape[0], "| After:", air_clean.shape[0])

print("\nAir Quality Mean Values:")
print(air_clean.mean().round(4))

print("\nAir Quality Std Deviation:")
print(air_clean.std().round(4))

# EDA数据统计
eda_clean = eda_df.dropna(axis=0)
print("\nEDA Cleaning | Before:", eda_df.shape[0], "| After:", eda_clean.shape[0])

print("\nEDA Mean Values:")
print(eda_clean.mean().round(4))

print("\nEDA Std Deviation:")
print(eda_clean.std().round(4))

print("\nWeek 1 COMPLETED!")
# Out:
# All files read successfully!
# Air data shape: (52584, 17)
# EDA data shape: (31495, 1)
# HR data shape: (7866, 1)
#
# Cleaning | Before: 52584 | After: 19038
#
# Air Quality Mean Values:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 28
#      25 print("\nCleaning | Before:", air_df.shape[0], "| After:", air_clean.shape[0])
#      27 print("\nAir Quality Mean Values:")
# ---> 28 print(air_clean.mean().round(4))
#      30 print("\nAir Quality Std Deviation:")
#      31 print(air_clean.std().round(4))
#
# File ~\miniconda3\envs\hydro_ai\lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)
#   11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
# ...

# %%
import pandas as pd
import numpy as np

# ==================================================
# 路径（已验证完全正确，不要修改）
# ==================================================
air_path = r"D:\Hydro_AI_Project\pm2.5\ShenyangPM20100101_20151231.csv"
eda_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\EDA.csv"
hr_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\HR.csv"
temp_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\TEMP.csv"
acc_path = r"D:\Hydro_AI_Project\WESAD\S2_E4_Data\ACC.csv"

# ==================================================
# 1. 读取数据（已验证成功）
# ==================================================
air_df = pd.read_csv(air_path)
eda_df = pd.read_csv(eda_path)
hr_df = pd.read_csv(hr_path)
temp_df = pd.read_csv(temp_path)
acc_df = pd.read_csv(acc_path)

# ==================================================
# 2. 打印数据读取成功信息
# ==================================================
print("="*60)
print("✅ All files read successfully!")
print(f"📊 Air quality data shape: {air_df.shape}")
print(f"📊 EDA data shape: {eda_df.shape}")
print(f"📊 HR data shape: {hr_df.shape}")

# ==================================================
# 3. 第1周测试节点：空值过滤 + 数值列均值/标准差
# ==================================================
print("\n" + "="*60)
print("📊 Week 1 Test Node: Air Quality Data Statistics")

# 3.1 过滤空值
air_clean = air_df.dropna(axis=0)
print(f"🔧 Cleaning | Before: {air_df.shape[0]} | After: {air_clean.shape[0]}")

# 3.2 只选择数值型列计算均值/标准差（彻底解决TypeError！）
air_numeric = air_clean.select_dtypes(include=[np.number])

print("\n🔍 Air Quality Numeric Columns Mean Values (rounded to 4 decimals):")
print(air_numeric.mean().round(4))

print("\n🔍 Air Quality Numeric Columns Std Deviation (rounded to 4 decimals):")
print(air_numeric.std().round(4))

print("\n🎉 Week 1 Test Node (Air Quality) PASSED!")

# ==================================================
# 4. EDA数据统计（生物传感部分）
# ==================================================
print("\n" + "="*60)
print("📊 Week 1 Test Node: EDA Data Statistics")

eda_clean = eda_df.dropna(axis=0)
print(f"🔧 Cleaning | Before: {eda_df.shape[0]} | After: {eda_clean.shape[0]}")

print("\n🔍 EDA Mean Value (rounded to 4 decimals):")
print(eda_clean.mean().round(4))

print("\n🔍 EDA Std Deviation (rounded to 4 decimals):")
print(eda_clean.std().round(4))

print("\n🎉 Week 1 Test Node (EDA) PASSED!")
print("\n🎉 🎉 Week 1 100% COMPLETED! First Phase Week 1 Officially Finished!")
# Out:
# ...
# ✅ All files read successfully!
# 📊 Air quality data shape: (52584, 17)
# 📊 EDA data shape: (31495, 1)
# 📊 HR data shape: (7866, 1)
#
# ...
# 📊 Week 1 Test Node: Air Quality Data Statistics
# 🔧 Cleaning | Before: 52584 | After: 19038
#
# 🔍 Air Quality Numeric Columns Mean Values (rounded to 4 decimals):
# No               41013.9396
# year              2014.1449
# month                6.9275
# day                 15.9837
# hour                11.5277
# season               2.5479
# PM_Taiyuanjie       78.0262
# PM_US Post          74.9087
# PM_Xiaoheyan        72.0223
# DEWP                 0.7678
# HUMI                59.9937
# PRES              1016.3433
# TEMP                 9.2537
# Iws                 22.0980
# precipitation        0.0572
# Iprec                0.2670
# dtype: float64
#
# 🔍 Air Quality Numeric Columns Std Deviation (rounded to 4 decimals):
# No               6573.3054
# year                0.7667
# month               3.4665
# day                 8.8615
# ...
